# %%
import json
import pandas as pd

# %% [markdown]
# # Esperimenti sulla vista creata con una selezione di 20 variabili

# %%
exp20 = pd.read_json('best_result/esperimenti20var.json')
exp20
# Out:
#                         Totale              Totale_0         TotaliDistretti  \
# c                          0.1                   0.1                     0.1
# fuzzifier      LinearFuzzifier  ExponentialFuzzifier    ExponentialFuzzifier
# k          GaussianKernel(0.1)     GaussianKernel(1)  HyperbolicKernel(1, 1)
# score                -0.310563             -0.265833                -0.31087
#
#                 TotaliDistretti_0               LesioniPCA10  \
# c                             0.1                        0.1
# fuzzifier    ExponentialFuzzifier            LinearFuzzifier
# k          HyperbolicKernel(1, 1)  HyperbolicKernel(1, 0.01)
# score                   -0.256225                  -0.298575
#
#                  LesioniPCA10_0               LesioniPCA20   LesioniPCA20_0
# c                           0.1                        0.1              0.1
# fuzzifier  ExponentialFuzzifier       ExponentialFuzzifier  LinearFuzzifier
# ...

# %% [markdown]
# ### Esperimenti anagrafici

# %%
expanag = pd.read_json('best_result/esperimenti_anagrafici.json')
expanag
# Out:
#            PesoLesioni20_0 AltezzaLesioni20_0   BMILesioni20_0  \
# c                      0.1                0.1              0.1
# fuzzifier  LinearFuzzifier    LinearFuzzifier  LinearFuzzifier
# k           LinearKernel()     LinearKernel()   LinearKernel()
# score             -0.24674          -0.247668        -0.247668
#
#           PesoAltezzaLesioni20_0   AllLesioni20_0
# c                            0.1              0.1
# fuzzifier        LinearFuzzifier  LinearFuzzifier
# k                 LinearKernel()   LinearKernel()
# score                  -0.243004        -0.256033

# %% [markdown]
# # Esperimenti sulla vista creata con una selezione di 13 variabili

# %%
exp13 = pd.read_json('best_result/esperimenti13var.json')
exp13
# Out:
#                           df13All_0              df13lesioni_0  \
# c                               0.1                        0.1
# fuzzifier           LinearFuzzifier            LinearFuzzifier
# k          HyperbolicKernel(1, 0.1)  HyperbolicKernel(1, 0.01)
# score                     -0.259601                  -0.269655
#
#                    df13_coste_0
# c                           0.1
# fuzzifier  ExponentialFuzzifier
# k            GaussianKernel(10)
# score                 -0.247117

# %% [markdown]
# ## Esperimenti sulla vista del dataset con feature delle lesioni ottenute tramite PCA

# %%
exppca = pd.read_json('best_result/esperimentipca.json')
exppca
# Out:
#                          dfPCA1All_0            dfPCA1Lesioni_0  \
# c                                0.1                        0.1
# fuzzifier            LinearFuzzifier            LinearFuzzifier
# k          HyperbolicKernel(1, 0.01)  HyperbolicKernel(1, 0.01)
# score                      -0.263058                  -0.255135
#
#                         dfPCA2All_0            dfPCA2Lesioni_0
# c                               0.1                        0.1
# fuzzifier      ExponentialFuzzifier            LinearFuzzifier
# k          HyperbolicKernel(1, 0.1)  HyperbolicKernel(1, 0.01)
# score                     -0.242371                  -0.233964

# %% [markdown]
# # Vista significativa della fuzzifier table

# %%
ft = pd.read_json('best_result/best_fuzzifiers.json')
ft
# Out:
#                                      LesioniPCA20  LesioniPCA20_0  \
#  QuantileConstantPiecewiseFuzzifier     -0.353704       -0.360994
# CrispFuzzifier                          -0.429352       -0.540521
# ExponentialFuzzifier                    -0.285350       -0.247454
# LinearFuzzifier                         -0.286122       -0.241568
# QuantileLinearPiecewiseFuzzifier        -0.358636       -0.360994
#
#                                      dfPCA2Lesioni  dfPCA2Lesioni_0
#  QuantileConstantPiecewiseFuzzifier      -0.418340        -0.246146
# CrispFuzzifier                           -0.345666        -0.276427
# ExponentialFuzzifier                     -0.271861        -0.233964
# LinearFuzzifier                          -0.274811        -0.231479
# QuantileLinearPiecewiseFuzzifier         -0.414097        -0.268192

# %% [markdown]
# # Best Experiments

# %%
best = pd.read_json('best_result/best_experiments.json')
best
# Out:
#                                          FuzzyInductor_Esperimento1  \
# esperimento                       Df20Variabili_Lesioni20Componenti
# train_err                                                  0.300366
# test_err                                                    0.25641
# scaling           QuantileTransformer(output_distribution='normal')
# dim_reduction                                  PCA(n_components=20)
# c_class0                                                        0.1
# c_class1                                                        0.1
# fuzzifier_class0                                    LinearFuzzifier
# fuzzifier_class1                               ExponentialFuzzifier
# kernel_class0                                        LinearKernel()
# kernel_class1                                 HyperbolicKernel(1,0)
# defuzzification                                      max_membership
#
#                  FuzzyInductor_Esperimento2
# ...
